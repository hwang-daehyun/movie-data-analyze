# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("C:\\Users\\User\\Desktop\\데이터 분석 연습\\인천광역시_직업별 취업자 통계_20211231.csv", encoding = 'cp949')
data

# %%
data_coloms = data.columns
list(data_coloms)
data_coloms

# %%
data_col = []

for i in data_coloms:
   ootd = i.split('(')[0]
   data_col.append(ootd)


data_col

# %%
# 백분률 전부 천명 기준으로 만들기
data.head()

# %%
for i in data:
    if '(퍼센트)' in i:
        data[i] = round(data['합계_취업자수(천명)']* data[i],0)
        print(data[i])

# %%
data.rename(columns=dict(zip(data_coloms,data_col)), inplace=True)
data.head()

# %%
import matplotlib

data_1 = list(data.iloc[0,1:])
data_2 = list(data.iloc[1,1:])
data_3 = list(data.iloc[2,1:])
data_4 = list(data.iloc[3,1:])

data_colo = list(data.columns[1:])


plt.rcParams['font.family'] = 'Malgun Gothic'
matplotlib.rcParams['font.size'] = 15 #글자 크기
matplotlib.rcParams['axes.unicode_minus'] = False 

plt.pie(data_1, labels=data_colo, autopct='%1.1f%%')
plt.show()
# Out:
# 현재 셀 또는 이전 셀에서 코드를 실행하는 동안 Kernel이 충돌했습니다.
#
# 셀의 코드를 검토하여 가능한 오류 원인을 식별하세요.
#
# 자세한 내용을 보려면 <a href='https://aka.ms/vscodeJupyterKernelCrash'>여기</a>를 클릭하세요.
#
# 자세한 내용은 Jupyter <a href='command:jupyter.viewOutput'>로그</a>를 참조하세요.

# %%
# Out:
# 19
