# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("C:\\Users\\User\\Desktop\\데이터 분석 연습\\births-and-deaths-projected-to-2100.csv")
df
# Out:
#             Entity Code  Year  \
# 0      Afghanistan  AFG  1950
# 1      Afghanistan  AFG  1951
# 2      Afghanistan  AFG  1952
# 3      Afghanistan  AFG  1953
# 4      Afghanistan  AFG  1954
# ...            ...  ...   ...
# 38651     Zimbabwe  ZWE  2096
# 38652     Zimbabwe  ZWE  2097
# 38653     Zimbabwe  ZWE  2098
# 38654     Zimbabwe  ZWE  2099
# 38655     Zimbabwe  ZWE  2100
#
#        Deaths - Sex: all - Age: all - Variant: estimates  \
# 0                                               290972.0
# 1                                               288752.0
# 2                                               288059.0
# 3                                               287712.0
# 4                                               289189.0
# ...                                                  ...
# 38651                                                NaN
# 38652                                                NaN
# 38653                                                NaN
# ...

# %%
df.columns
# Out:
# Index(['Entity', 'Code', 'Year',
#        'Deaths - Sex: all - Age: all - Variant: estimates',
#        'Deaths - Sex: all - Age: all - Variant: medium',
#        'Births - Sex: all - Age: all - Variant: estimates',
#        'Births - Sex: all - Age: all - Variant: medium'],
#       dtype='object')

# %%
df_columns = ['Entity', 'Code', 'Year',
       'Deaths - Sex: all - Age: all - Variant: estimates',
       'Deaths - Sex: all - Age: all - Variant: medium',
       'Births - Sex: all - Age: all - Variant: estimates',
       'Births - Sex: all - Age: all - Variant: medium']


for i in df_columns:
    print(i)
    print('*'*20)
    print(df[i].unique())
# Out:
# Entity
# ********************
# ['Afghanistan' 'Africa (UN)' 'Albania' 'Algeria' 'American Samoa'
#  'Americas (UN)' 'Andorra' 'Angola' 'Anguilla' 'Antigua and Barbuda'
#  'Argentina' 'Armenia' 'Aruba' 'Asia (UN)' 'Australia' 'Austria'
#  'Azerbaijan' 'Bahamas' 'Bahrain' 'Bangladesh' 'Barbados' 'Belarus'
#  'Belgium' 'Belize' 'Benin' 'Bermuda' 'Bhutan' 'Bolivia'
#  'Bonaire Sint Eustatius and Saba' 'Bosnia and Herzegovina' 'Botswana'
#  'Brazil' 'British Virgin Islands' 'Brunei' 'Bulgaria' 'Burkina Faso'
#  'Burundi' 'Cambodia' 'Cameroon' 'Canada' 'Cape Verde' 'Cayman Islands'
#  'Central African Republic' 'Chad' 'Chile' 'China' 'Colombia' 'Comoros'
#  'Congo' 'Cook Islands' 'Costa Rica' "Cote d'Ivoire" 'Croatia' 'Cuba'
#  'Curacao' 'Cyprus' 'Czechia' 'Democratic Republic of Congo' 'Denmark'
#  'Djibouti' 'Dominica' 'Dominican Republic' 'East Timor' 'Ecuador' 'Egypt'
#  'El Salvador' 'Equatorial Guinea' 'Eritrea' 'Estonia' 'Eswatini'
# ...

# %%
for i in df_columns:
    print(f'{i}:')
    print(df[i].nunique())
    print('*'*20)
# Out:
# Entity:
# 256
# ********************
# Code:
# 238
# ********************
# Year:
# 151
# ********************
# Deaths - Sex: all - Age: all - Variant: estimates:
# 15514
# ********************
# Deaths - Sex: all - Age: all - Variant: medium:
# 17101
# ********************
# Births - Sex: all - Age: all - Variant: estimates:
# 16471
# ********************
# Births - Sex: all - Age: all - Variant: medium:
# 16707
# ********************
